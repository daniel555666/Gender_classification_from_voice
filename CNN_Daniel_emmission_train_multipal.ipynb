# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
#import seaborn as sns
import os
import random
import cv2
import json
from sklearn.model_selection import train_test_split
from torch import nn
import constants as c
import torch
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


NUM_OF_SPEAKERS = 2

# %%
# Load data into dataframe
training_data_folder_array = [r'C:\Users\User\Gender_classification_from_voice\data\music_json_arabic_data',
                              r'C:\Users\User\Gender_classification_from_voice\data\music_json_spanish_data',
                        r'C:\Users\User\Gender_classification_from_voice\data\music_json_russian_data',
                        r'C:\Users\User\Gender_classification_from_voice\data\music_json_english_data',
                        r'C:\Users\User\Gender_classification_from_voice\data\music_json_french_data']

def load_data():
    """
    Loads data and preprocess. Returns train and test data along with labels.
    """
    images = []
    labels = []
    size = 29,449
    num=0
    count=0

    print("LOADING DATA FROM : ",end = "")


    # this code for all the languages load
    for path in training_data_folder_array:
        num =0
        print("load from: ",path)
        for folder in os.listdir(path): ## to check 
            if folder[0] == '.':
                continue
            print(folder, end = ' | ')
            for json_file in os.listdir(path + "/" + folder):
                temp_json_file = json.load(open(path + '/' + folder + '/' + json_file))
                temp_np_array = np.array(temp_json_file)
                temp = [cv2.resize(temp_np_array[0], size)]
                temp_img = np.array(temp)
                # plt.imshow(cv2.cvtColor(temp_img, cv2.COLOR_BGR2RGB))
                # plt.show()
                images.append(temp_img)
                labels.append(num)
                count+=1 #count the number of photos
                if count% 5000==0:
                    print("data number: ",count ,"was load")
            num+=1
    
    
    images = np.array(images)
    # images = images.astype('float32')/255
    
    
    X_train, X_test, Y_train, Y_test = train_test_split(images, labels, test_size = 0.3, random_state=42)
    X_test, X_validation, Y_test, Y_validation = train_test_split(X_test, Y_test, test_size = 0.8,random_state=42)
    
    
    print()
    print('Loaded', len(X_train),'images for training,','Train data shape =',X_train.shape)
    print('Loaded', len(X_validation),'images for validation','validation data shape =',X_validation.shape)
    print('Loaded', len(X_test),'images for testing','Test data shape =',X_test.shape)
    print('\n')

    
    return X_train, X_test, Y_train, Y_test, X_validation, Y_validation

X_train, X_test, Y_train, Y_test, X_validation, Y_validation= load_data()
# Out:
# LOADING DATA FROM : load from:  C:\Users\User\Gender_classification_from_voice\data\music_json_arabic_data
# M | data number:  5000 was load
# data number:  10000 was load
# data number:  15000 was load
# W | data number:  20000 was load
# data number:  25000 was load
# load from:  C:\Users\User\Gender_classification_from_voice\data\music_json_spanish_data
# M | data number:  30000 was load
# data number:  35000 was load
# data number:  40000 was load
# data number:  45000 was load
# data number:  50000 was load
# W | data number:  55000 was load
# data number:  60000 was load
# data number:  65000 was load
# data number:  70000 was load
# data number:  75000 was load
# load from:  C:\Users\User\Gender_classification_from_voice\data\music_json_russian_data
# M | data number:  80000 was load
# data number:  85000 was load
# data number:  90000 was load
# data number:  95000 was load
# data number:  100000 was load
# W | data number:  105000 was load
# data number:  110000 was load
# data number:  115000 was load
# data number:  120000 was load
# data number:  125000 was load
# load from:  C:\Users\User\Gender_classification_from_voice\data\music_json_english_data
# M | data number:  130000 was load
# data number:  135000 was load
# data number:  140000 was load
# data number:  145000 was load
# W | data number:  150000 was load
# data number:  155000 was load
# data number:  160000 was load
# data number:  165000 was load
# load from:  C:\Users\User\Gender_classification_from_voice\data\music_json_french_data
# M | data number:  170000 was load
# data number:  175000 was load
# data number:  180000 was load
# data number:  185000 was load
# data number:  190000 was load
# data number:  195000 was load
# W | data number:  200000 was load
# data number:  205000 was load
# data number:  210000 was load
# data number:  215000 was load
# data number:  220000 was load
# data number:  225000 was load
#
# Loaded 157786 images for training, Train data shape = (157786, 1, 449, 29)
# Loaded 54099 images for validation validation data shape = (54099, 1, 449, 29)
# Loaded 13524 images for testing Test data shape = (13524, 1, 449, 29)

# %%
DROP_OUT = 0.5

class Convolutional_Speaker_Identification(nn.Module):

    def cal_paddind_shape(self, new_shape, old_shape, kernel_size, stride_size):
        return (stride_size * (new_shape - 1) + kernel_size - old_shape) / 2

    def __init__(self):
        super().__init__()
        self.conv_2d_1 = nn.Conv2d(1, 96, kernel_size=(7, 7), stride=(2, 2), padding=2)
        self.bn_1 = nn.BatchNorm2d(96)
        self.max_pool_2d_1 = nn.MaxPool2d(kernel_size=(3, 3), stride=(2, 2))

        self.conv_2d_2 = nn.Conv2d(96, 256, kernel_size=(5, 5), stride=(2, 2), padding=2)
        self.bn_2 = nn.BatchNorm2d(256)
        self.max_pool_2d_2 = nn.MaxPool2d(kernel_size=(3, 3), stride=(2, 2))

        self.conv_2d_3 = nn.Conv2d(256, 384, kernel_size=(3, 3), padding=2)
        self.bn_3 = nn.BatchNorm2d(384)

        self.conv_2d_4 = nn.Conv2d(384, 256, kernel_size=(3, 3), padding=2)
        self.bn_4 = nn.BatchNorm2d(256)

        self.conv_2d_5 = nn.Conv2d(256, 256, kernel_size=(3, 3), padding=2)
        self.bn_5 = nn.BatchNorm2d(256)
        self.max_pool_2d_3 = nn.MaxPool2d(kernel_size=(5, 3), stride=(3, 2))

        self.conv_2d_6 = nn.Conv2d(256, 4096, kernel_size=(9, 1), padding=0)
        self.drop_1 = nn.Dropout(p=DROP_OUT)

        self.global_avg_pooling_2d = nn.AdaptiveAvgPool2d((1, 1))
        self.dense_1 = nn.Linear(4096, 1024)
        self.drop_2 = nn.Dropout(p=DROP_OUT)

        self.dense_2 = nn.Linear(1024, NUM_OF_SPEAKERS)

    def forward(self, X):
        x = nn.ReLU()(self.conv_2d_1(X))
        x = self.bn_1(x)
        x = self.max_pool_2d_1(x)

        x = nn.ReLU()(self.conv_2d_2(x))
        x = self.bn_2(x)
        x = self.max_pool_2d_2(x)

        x = nn.ReLU()(self.conv_2d_3(x))
        x = self.bn_3(x)

        x = nn.ReLU()(self.conv_2d_4(x))
        x = self.bn_4(x)

        x = nn.ReLU()(self.conv_2d_5(x))
        x = self.bn_5(x)
        x = self.max_pool_2d_3(x)

        x = nn.ReLU()(self.conv_2d_6(x))
        x = self.drop_1(x)
        x = self.global_avg_pooling_2d(x)

        x = x.view(-1, x.shape[1])  # output channel for flatten before entering the dense layer
        x = nn.ReLU()(self.dense_1(x))
        x = self.drop_2(x)

        x = self.dense_2(x)
        y = nn.LogSoftmax(dim=1)(x)   # consider using Log-Softmax

        return y

    # def get_epochs(self):
    #     return epochs
    # def get_learning_rate(self):
    #     return lr
    # def get_batch_size(self):
    #     return batch_size
    # def to_string(self):
    #     return "Convolutional_Speaker_Identification_Log_Softmax_Model-epoch_"

# %%
import torch.nn as nn
import torch.optim as optim

# Define loss, optimizer and metrics
model = Convolutional_Speaker_Identification()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
loss_fn = nn.CrossEntropyLoss()
model_save_name='model.all_with_music.pt'
batch_size = 32

loss_fn = nn.CrossEntropyLoss()
metrics = ["accuracy"]

import torch

if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("using cuda")
else:
    print("not using cuda")
    device = torch.device("cpu")


import pickle

# Split the train set into four parts
X_train_parts = np.array_split(X_train, 20)
Y_train_parts = np.array_split(Y_train, 20)
# Split the val set into four parts
X_val_parts = np.array_split(X_validation, 5)
Y_val_parts = np.array_split(Y_validation, 5)


# Save each part of the train set to a separate pickle file
for i, (X_part, Y_part) in enumerate(zip(X_train_parts, Y_train_parts)):
    with open(f'train_part{i+1}.pkl', 'wb') as f:
        pickle.dump((X_part, Y_part), f)

# Save each part of the val set to a separate pickle file
for i, (X_part, Y_part) in enumerate(zip(X_val_parts, Y_val_parts)):
    with open(f'val_part{i+1}.pkl', 'wb') as f:
        pickle.dump((X_part, Y_part), f)
# Out:
# using cuda

# %%
# train and validation of the model

best_validation_accuracy = -1.0

model = model.to(torch.float)
epochs = 20
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training and validation loop
for t in range(2):

    if t ==1 : # smaller lr 
        optimizer = optim.Adam(model.parameters(), lr=0.0001)
        epochs=15

    for epoch in range(epochs):
        model.train()  # Set the model to training mode
        train_loss = 0.0
        correct = 0
        total = 0
        
        ## Training ##
        for part in range(1,21):

            ## load the data  parts from pkl
            with open(f'train_part{part}.pkl', 'rb') as f:
                data_x, data_y = pickle.load(f)
                print("load/train pkl part: ",part)

                # Define your training data loader
                data_x = torch.tensor(data_x).to(device)
                data_y = torch.tensor(data_y,dtype=torch.long).to(device)
                dataset = torch.utils.data.TensorDataset(data_x, data_y)
                train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

            for images, labels in train_loader:
                # Forward pass
                images = images.to(torch.float)
                outputs = model(images)
                loss = loss_fn(outputs, labels)
                
                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                train_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        train_accuracy = correct / total
        train_loss /= len(train_loader)

        print(f"Epoch {epoch+1}/{epochs}:")
        print(f"Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}")
        data_x=None #empty gpu
        data_y=None
        ## Validation ##
        model.eval()  # Set the model to evaluation mode
        validation_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():

            for part in range(1,6):

                # load the data  parts from pkl
                with open(f'val_part{part}.pkl', 'rb') as f:
                    val_x, val_y = pickle.load(f)
                    print("load/eval val pkl part: ",part)

                # Define your validation data loader
                val_x = torch.tensor(val_x).to(device)
                val_y = torch.tensor(val_y, dtype=torch.long).to(device)
                validation_dataset = torch.utils.data.TensorDataset(val_x, val_y)
                validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)    

                for images, labels in validation_loader:
                    images = images.to(torch.float)
                    outputs = model(images)
                    loss = loss_fn(outputs, labels)
                    validation_loss += loss.item()
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

        validation_accuracy = correct / total
        validation_loss /= len(validation_loader)
        print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.4f}")
        print()
        
        # save the best model and test in th end
        if best_validation_accuracy < validation_accuracy :
            best_validation_accuracy = validation_accuracy
            print(f"best model now with val_acc: {best_validation_accuracy:.4f}")
            torch.save(model.state_dict(), model_save_name)
        print()
# Out:
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 1/20:
# Training Loss: 10.7683, Training Accuracy: 0.7429
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.3508, Validation Accuracy: 0.7823
#
# best model now with val_acc: 0.7823
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 2/20:
# Training Loss: 9.4222, Training Accuracy: 0.7868
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.1957, Validation Accuracy: 0.7986
#
# best model now with val_acc: 0.7986
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 3/20:
# Training Loss: 8.9287, Training Accuracy: 0.7994
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.8220, Validation Accuracy: 0.7414
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 4/20:
# Training Loss: 8.5408, Training Accuracy: 0.8088
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.2802, Validation Accuracy: 0.7856
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 5/20:
# Training Loss: 8.2763, Training Accuracy: 0.8169
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.3476, Validation Accuracy: 0.7826
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 6/20:
# Training Loss: 7.9454, Training Accuracy: 0.8261
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.0935, Validation Accuracy: 0.8194
#
# best model now with val_acc: 0.8194
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 7/20:
# Training Loss: 7.6482, Training Accuracy: 0.8326
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.1920, Validation Accuracy: 0.8284
#
# best model now with val_acc: 0.8284
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 8/20:
# Training Loss: 7.3852, Training Accuracy: 0.8407
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.4926, Validation Accuracy: 0.7738
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 9/20:
# Training Loss: 7.1367, Training Accuracy: 0.8474
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.0370, Validation Accuracy: 0.8295
#
# best model now with val_acc: 0.8295
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 10/20:
# Training Loss: 6.8261, Training Accuracy: 0.8550
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.0798, Validation Accuracy: 0.8253
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 11/20:
# Training Loss: 6.4786, Training Accuracy: 0.8630
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.1701, Validation Accuracy: 0.8166
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 12/20:
# Training Loss: 6.1418, Training Accuracy: 0.8716
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.4980, Validation Accuracy: 0.8192
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 13/20:
# Training Loss: 5.8115, Training Accuracy: 0.8786
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.4108, Validation Accuracy: 0.8220
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 14/20:
# Training Loss: 5.4460, Training Accuracy: 0.8873
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.5120, Validation Accuracy: 0.8239
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 15/20:
# Training Loss: 5.0017, Training Accuracy: 0.8975
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 6.8660, Validation Accuracy: 0.8166
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 16/20:
# Training Loss: 4.5626, Training Accuracy: 0.9074
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.5844, Validation Accuracy: 0.8206
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 17/20:
# Training Loss: 4.1520, Training Accuracy: 0.9158
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 2.6469, Validation Accuracy: 0.8143
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 18/20:
# Training Loss: 3.8386, Training Accuracy: 0.9227
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 3.1940, Validation Accuracy: 0.8152
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 19/20:
# Training Loss: 3.4243, Training Accuracy: 0.9320
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 5.0570, Validation Accuracy: 0.7992
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 20/20:
# Training Loss: 3.0880, Training Accuracy: 0.9393
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 3.5971, Validation Accuracy: 0.8115
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 1/15:
# Training Loss: 2.1024, Training Accuracy: 0.9590
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 5.1849, Validation Accuracy: 0.8131
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 2/15:
# Training Loss: 1.5082, Training Accuracy: 0.9711
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 5.6206, Validation Accuracy: 0.8125
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 3/15:
# Training Loss: 1.1893, Training Accuracy: 0.9777
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 6.3865, Validation Accuracy: 0.8135
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 4/15:
# Training Loss: 1.0042, Training Accuracy: 0.9808
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 7.3090, Validation Accuracy: 0.8105
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 5/15:
# Training Loss: 0.8294, Training Accuracy: 0.9844
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 8.0402, Validation Accuracy: 0.8135
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 6/15:
# Training Loss: 0.7425, Training Accuracy: 0.9860
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 8.2167, Validation Accuracy: 0.8121
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 7/15:
# Training Loss: 0.6481, Training Accuracy: 0.9878
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 8.7505, Validation Accuracy: 0.8120
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 8/15:
# Training Loss: 0.5801, Training Accuracy: 0.9894
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 9.0890, Validation Accuracy: 0.8125
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 9/15:
# Training Loss: 0.5112, Training Accuracy: 0.9907
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 8.2643, Validation Accuracy: 0.8101
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 10/15:
# Training Loss: 0.4914, Training Accuracy: 0.9912
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 9.3120, Validation Accuracy: 0.8104
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 11/15:
# Training Loss: 0.4415, Training Accuracy: 0.9921
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 9.7196, Validation Accuracy: 0.8091
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 12/15:
# Training Loss: 0.4045, Training Accuracy: 0.9928
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 10.2548, Validation Accuracy: 0.8117
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 13/15:
# Training Loss: 0.3955, Training Accuracy: 0.9934
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 9.5536, Validation Accuracy: 0.8113
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 14/15:
# Training Loss: 0.3413, Training Accuracy: 0.9941
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 10.2997, Validation Accuracy: 0.8117
#
#
# load/train pkl part:  1
# load/train pkl part:  2
# load/train pkl part:  3
# load/train pkl part:  4
# load/train pkl part:  5
# load/train pkl part:  6
# load/train pkl part:  7
# load/train pkl part:  8
# load/train pkl part:  9
# load/train pkl part:  10
# load/train pkl part:  11
# load/train pkl part:  12
# load/train pkl part:  13
# load/train pkl part:  14
# load/train pkl part:  15
# load/train pkl part:  16
# load/train pkl part:  17
# load/train pkl part:  18
# load/train pkl part:  19
# load/train pkl part:  20
# Epoch 15/15:
# Training Loss: 0.3467, Training Accuracy: 0.9940
# load/eval val pkl part:  1
# load/eval val pkl part:  2
# load/eval val pkl part:  3
# load/eval val pkl part:  4
# load/eval val pkl part:  5
# Validation Loss: 10.0987, Validation Accuracy: 0.8105

# %%
test_x = torch.tensor(X_test).to(device)
test_y = torch.tensor(Y_test).to(device)

# Define your test data loader
test_dataset = torch.utils.data.TensorDataset(test_x, test_y)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

#Test our best model

#start test
model.eval()
with torch.no_grad():
    true_labels = []
    predicted_labels = []

    for images, labels in test_loader:
        images = images.to(torch.float)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        true_labels.extend(labels.cpu().tolist())
        predicted_labels.extend(predicted.cpu().tolist())

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='macro')
recall = recall_score(true_labels, predicted_labels, average='macro')
f1 = f1_score(true_labels, predicted_labels, average='macro')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")

# Create a dictionary to store the results
results = {
    "model name": model_save_name,
    "accuracy": f"{accuracy:.4f}",
    "precision": f"{precision:.4f}",
    "recall": f"{recall:.4f}",
    "f1": f"{f1:.4f}"
}

# Save the dictionary to a text file
with open("save.txt", "a") as file:
    file.write(str(results) + "\n")
# Out:
# Accuracy: 0.8119
# Precision: 0.8119
# Recall: 0.8119
# F1-score: 0.8119
